# %% [markdown]
# # Lab 3: Logistic Regression
#
# ### Dataset:
# Predicting the weather: https://www.kaggle.com/datasets/ananthr1/weather-prediction
#
# Group: Benjamin Kuo & Nick Benso

# %% [markdown]
# ## Business Understanding
#
# This dataset contains weather data in Seattle dating from the beginning of 2012 to the end of 2015. It includes data such as the amount of precipitation, the maximum and minimum temperatures, the wind speed, and the type of weather on a given day. The prediction task for this data is to predict the type of weather a certain day will have based on all the other variables. The types of weather to be predicted are drizzle, fog, rain, snow, and sun. The goal of this prediction task will be to help solve the unpredictability of weather. Meterologists have been studying weather for centuries, and their predictions have gotten very accurate recently through the use of large historical datasets amongst other significant scientific breakthroughs. Therefore, the third party of meterologists would be interested in these results as it would allow them to better understand what factors in Seattle cause the weather to behave a certain way, and how these factors can be used to predict future weather patterns. Meterologists could then share this information to other third parties that may be interested in these results, such as citizens or visitors of Seattle, as these people would be able to use this classification task to predict what the weather will look like in the next few days, therefore potentially altering their schedule to adjust for the predicted weather. This model would be used mostly for offline analysis. Since the dates only range 4 years, it does not fully capture or embrace weather trends and patterns. There are important factors that are not included in this model, such as seasonality, global warming, pure randomness, etc. that may significantly affect the weather. Therefore, the classifier needs not perform near-perfect as there are still many factors that need to be taken into account outside this model. In general, however, the model presents some significant factors that influence weather, so a consistent accuracy of over 80% would be a reasonable estimate for the classification task.

# %%
# %config Completer.use_jedi = False
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from datetime import datetime
from datetime import date

df = pd.read_csv('seattle-weather.csv') # read in the csv file
print(df.info())

# separate data types
date_features = 'date'
numerical_features = ['precipitation','temp_max','temp_min','wind']
weather_features = ['weather']
df['weather'].replace(['drizzle', 'fog', 'rain', 'snow', 'sun'],
                        [0, 1, 2, 3, 4], inplace=True)

# define with correct data types
del df['date']
df[numerical_features] = df[numerical_features].astype(np.float64)
df[weather_features] = df[weather_features].astype(np.int64)

df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           1461 non-null   object
#  1   precipitation  1461 non-null   float64
#  2   temp_max       1461 non-null   float64
#  3   temp_min       1461 non-null   float64
#  4   wind           1461 non-null   float64
#  5   weather        1461 non-null   object
# dtypes: float64(4), object(2)
# memory usage: 68.6+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1461 entries, 0 to 1460
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   precipitation  1461 non-null   float64
#  1   temp_max       1461 non-null   float64
#  2   temp_min       1461 non-null   float64
#  3   wind           1461 non-null   float64
#  4   weather        1461 non-null   int64
# dtypes: float64(4), int64(1)
# ...

# %% [markdown]
# The final dataset used to for this model involves numerical data in the form of precipitation levels, maximum temperatures, minimum temperatures, and wind level. The date data was removed as although it may have some use as certain weather might be more often in certain seasons, it would be hard to encode it in a way that numerically made sense with the model. The classes to be predicted are the specific type of weather: drizzle, fog, rain, snow, sun. Since this categorical data is in the form of strings, they are each numerically coded to allow for processes as 1, 2, 3, and 4, respectively.

# %%
from sklearn.model_selection import ShuffleSplit

# we want to predict the X and y data as follows:
if 'weather' in df:
    y = df['weather'].to_numpy() # get the labels we want
    del df['weather'] # get rid of the class label
    
    norm_features = ['precipitation', 'temp_max', 'temp_min', 'wind' ]
    df[norm_features] = (df[norm_features]-df[norm_features].mean()) / df[norm_features].std()
    X = df.to_numpy() # use everything else to predict!

    ## X and y are now numpy matrices, by calling 'values' on the pandas data frames we
    #    have converted them into simple matrices to use with scikit learn
    
    
# to use the cross validation object in scikit learn, we need to grab an instance
#    of the object and set it up. This object will be able to split our data into 
#    training and testing splits
num_cv_iterations = 3
num_instances = len(y)
cv_object = ShuffleSplit(
                         n_splits=num_cv_iterations,
                         test_size  = 0.2)
                         
print(cv_object)
# Out:
# ShuffleSplit(n_splits=3, random_state=None, test_size=0.2, train_size=None)

# %%
#check percentage of each weather type
percent = np.zeros(5)
for i in y:
    if(i == 0):
        percent[0] += 1
    elif(i == 1):
        percent[1] += 1
    elif(i == 2):
        percent[2] += 1
    elif(i == 3):
        percent[3] += 1
    elif(i == 4):
        percent[4] += 1
mylabels = ['drizzle', 'fog', 'rain', 'snow', 'sun']
plt.pie(percent, labels = mylabels, autopct='%1.0f%%')
plt.show()

# %% [markdown]
# For our data, a 80/20 split could run into some problems as the data consists of 5 different classes, some of which take up much less than 20% of the dataset. This includes snow, drizzle, and fog weather types which come in at 2%, 4%, and 7% of the entire dataset. While the split method from sklearn does distribute the data randomly, due to the low percentage of these classes, it may turn out that the model is barely trained on one of these smaller prediction classes, which may make it hard to predict them in the test data. However, the main bulk of data to be predicted is either rain or sunshine, both of which should have sufficient training data. To prevent this problem, more data in the snow, fog, and drizzle classes should be recorded and added.

# %% [markdown]
# ## Modeling

# %%
class BinaryLogisticRegressionBase:
    # private:
    def __init__(self, eta, C, iterations=20):
        self.eta = eta
        self.iters = iterations
        self.C = C
        # internally we will store the weights as self.w_ to keep with sklearn conventions
    
    def __str__(self):
        return 'Base Binary Logistic Regression Object, Not Trainable'
    
    # convenience, private and static:
    @staticmethod
    def _sigmoid(theta):
        return 1/(1+np.exp(-theta)) 
    
    @staticmethod
    def _add_intercept(X):
        return np.hstack((np.ones((X.shape[0],1)),X)) # add bias term
    
    # public:
    def predict_proba(self, X, add_intercept=True):
        # add bias term if requested
        Xb = self._add_intercept(X) if add_intercept else X
        return self._sigmoid(Xb @ self.w_) # return the probability y=1
    
    def predict(self,X):
        return (self.predict_proba(X)>0.5) #return the actual prediction




class BinaryLogisticRegression:
    def __init__(self, eta, iterations=20, C=0.001):
        self.eta = eta
        self.iters = iterations
        self.C = C
        # internally we will store the weights as self.w_ to keep with sklearn conventions
        
    def __str__(self):
        if(hasattr(self,'w_')):
            return 'Binary Logistic Regression Object with coefficients:\n'+ str(self.w_) # is we have trained the object
        else:
            return 'Untrained Binary Logistic Regression Object'
        
    # convenience, private:
    @staticmethod
    def _add_bias(X):
        return np.hstack((np.ones((X.shape[0],1)),X)) # add bias term
    
    @staticmethod
    def _sigmoid(theta):
        # increase stability, redefine sigmoid operation
        return expit(theta) #1/(1+np.exp(-theta))
    
    # vectorized gradient calculation with regularization using L2 Norm
    def _get_gradient(self,X,y):
        ydiff = y-self.predict_proba(X,add_bias=False).ravel() # get y difference
        gradient = np.mean(X * ydiff[:,np.newaxis], axis=0) # make ydiff a column vector and multiply through
        
        gradient = gradient.reshape(self.w_.shape)
        gradient[1:] += -2 * self.w_[1:] * self.C
        
        return gradient
    
    # public:
    def predict_proba(self,X,add_bias=True):
        # add bias term if requested
        Xb = self._add_bias(X) if add_bias else X
        return self._sigmoid(Xb @ self.w_) # return the probability y=1
    
    def predict(self,X):
        return (self.predict_proba(X)>0.5) #return the actual prediction
    
    
    def fit(self, X, y):
        Xb = self._add_bias(X) # add bias term
        num_samples, num_features = Xb.shape
        
        self.w_ = np.zeros((num_features,1)) # init weight vector to zeros
        
        # for as many as the max iterations
        for _ in range(self.iters):
            gradient = self._get_gradient(Xb,y)
            self.w_ += gradient*self.eta # multiply by learning rate 
            # add bacause maximizing  

            
class StochasticLogisticRegression(BinaryLogisticRegression):
    # stochastic gradient calculation 
    def _get_gradient(self,X,y):
        idx = int(np.random.rand()*len(y)) # grab random instance
        ydiff = y[idx]-self.predict_proba(X[idx],add_bias=False) # get y difference (now scalar)
        gradient = X[idx] * ydiff[:,np.newaxis] # make ydiff a column vector and multiply through
        
        gradient = gradient.reshape(self.w_.shape)
        gradient[1:] += -2 * self.w_[1:] * self.C
        
        return gradient
    

from scipy.optimize import fmin_bfgs # maybe the most common bfgs algorithm in the world
from numpy import ma
class BFGSBinaryLogisticRegression(BinaryLogisticRegression):
    
    @staticmethod
    def objective_function(w,X,y,C):
        g = expit(X @ w)
        # invert this because scipy minimizes, but we derived all formulas for maximzing
        return -np.sum(ma.log(g[y==1]))-np.sum(ma.log(1-g[y==0])) + C*sum(w**2) 
        #-np.sum(y*np.log(g)+(1-y)*np.log(1-g))

    @staticmethod
    def objective_gradient(w,X,y,C):
        g = expit(X @ w)
        ydiff = y-g # get y difference
        gradient = np.mean(X * ydiff[:,np.newaxis], axis=0)
        gradient = gradient.reshape(w.shape)
        gradient[1:] += -2 * w[1:] * C
        return -gradient
    
    # just overwrite fit function
    def fit(self, X, y):
        Xb = self._add_bias(X) # add bias term
        num_samples, num_features = Xb.shape
        
        self.w_ = fmin_bfgs(self.objective_function, # what to optimize
                            np.zeros((num_features,1)), # starting point
                            fprime=self.objective_gradient, # gradient function
                            args=(Xb,y,self.C), # extra args for gradient and objective function
                            gtol=1e-03, # stopping criteria for gradient, |v_k|
                            maxiter=self.iters, # stopping criteria iterations
                            disp=False)
        
        self.w_ = self.w_.reshape((num_features,1))

            
from numpy.linalg import pinv
class HessianBinaryLogisticRegression(BinaryLogisticRegression):
    # just overwrite gradient function
    def _get_gradient(self,X,y):
        g = self.predict_proba(X,add_bias=False).ravel() # get sigmoid value for all classes
        hessian = X.T @ np.diag(g*(1-g)) @ X - 2 * self.C # calculate the hessian

        ydiff = y-g # get y difference
        gradient = np.sum(X * ydiff[:,np.newaxis], axis=0) # make ydiff a column vector and multiply through
        gradient = gradient.reshape(self.w_.shape)
        gradient[1:] += -2 * self.w_[1:] * self.C
        
        return pinv(hessian) @ gradient




# now lets do some vectorized coding
from scipy.special import expit

class VectorBinaryLogisticRegression(BinaryLogisticRegression):
    # inherit from our previous class to get same functionality
    @staticmethod
    def _sigmoid(theta):
        # increase stability, redefine sigmoid operation
        return expit(theta) #1/(1+np.exp(-theta))
    
    # but overwrite the gradient calculation
    def _get_gradient(self,X,y):
        ydiff = y-self.predict_proba(X,add_intercept=False).ravel() # get y difference
        gradient = np.mean(X * ydiff[:,np.newaxis], axis=0) # make ydiff a column vector and multiply through
        
        return gradient.reshape(self.w_.shape)


class LogisticRegression:
    def __init__(self, eta, iterations=20):
        self.eta = eta
        self.iters = iterations
        # internally we will store the weights as self.w_ to keep with sklearn conventions
    
    def __str__(self):
        if(hasattr(self,'w_')):
            return 'MultiClass Logistic Regression Object with coefficients:\n'+ str(self.w_) # is we have trained the object
        else:
            return 'Untrained MultiClass Logistic Regression Object'
        
    def fit(self,X,y):
        num_samples, num_features = X.shape
        self.unique_ = np.unique(y) # get each unique class value
        num_unique_classes = len(self.unique_)
        self.classifiers_ = [] # will fill this array with binary classifiers
        
        for i,yval in enumerate(self.unique_): # for each unique value
            y_binary = (y==yval) # create a binary problem
            # train the binary classifier for this class
            blr = VectorBinaryLogisticRegression(self.eta,
                                                 self.iters)
            blr.fit(X,y_binary)
            # add the trained classifier to the list
            self.classifiers_.append(blr)
            
        # save all the weights into one matrix, separate column for each class
        self.w_ = np.hstack([x.w_ for x in self.classifiers_]).T
        
    def predict_proba(self,X):
        probs = []
        for blr in self.classifiers_:
            probs.append(blr.predict_proba(X)) # get probability for each classifier
        
        return np.hstack(probs) # make into single matrix
    
    def predict(self,X):
        return self.unique_[np.argmax(self.predict_proba(X),axis=1)] # take argmax along row
    
class MultiClassLogisticRegression:
    def __init__(self, eta, iterations=20, 
                 C=0.0001, 
                 solver=BFGSBinaryLogisticRegression):
        self.eta = eta
        self.iters = iterations
        self.C = C
        self.solver = solver
        self.classifiers_ = []
        # internally we will store the weights as self.w_ to keep with sklearn conventions
    
    def __str__(self):
        if(hasattr(self,'w_')):
            return 'MultiClass Logistic Regression Object with coefficients:\n'+ str(self.w_) # is we have trained the object
        else:
            return 'Untrained MultiClass Logistic Regression Object'
        
    def fit(self,X,y):
        num_samples, num_features = X.shape
        self.unique_ = np.sort(np.unique(y)) # get each unique class value
        num_unique_classes = len(self.unique_)
        self.classifiers_ = []
        for i,yval in enumerate(self.unique_): # for each unique value
            y_binary = np.array(y==yval).astype(int) # create a binary problem
            # train the binary classifier for this class
            
            hblr = self.solver(eta=self.eta,iterations=self.iters,C=self.C)
            hblr.fit(X,y_binary)

            # add the trained classifier to the list
            self.classifiers_.append(hblr)
            
        # save all the weights into one matrix, separate column for each class
        self.w_ = np.hstack([x.w_ for x in self.classifiers_]).T
        
    def predict_proba(self,X):
        probs = []
        for hblr in self.classifiers_:
            probs.append(hblr.predict_proba(X).reshape((len(X),1))) # get probability for each classifier
        
        return np.hstack(probs) # make into single matrix
    
    def predict(self,X):
        return np.argmax(self.predict_proba(X),axis=1) # take argmax along row

    
class RegularizedBinaryLogisticRegression(VectorBinaryLogisticRegression):
    # extend init functions
    def __init__(self, C=0.0, **kwds):        
        # need to add to the original initializer 
        self.C = C
        # but keep other keywords
        super().__init__(**kwds) # call parent initializer
        
        
    # extend previous class to change functionality
    def _get_gradient(self,X,y):
        # call get gradient from previous class
        gradient = super()._get_gradient(X,y)
        
        # add in regularization (to all except bias term)
        gradient[1:] += -2 * self.w_[1:] * self.C
        return gradient


class RegularizedLogisticRegression(LogisticRegression):
    def __init__(self, C=0.0, **kwds):        
        # need to add to the original initializer 
        self.C = C
        # but keep other keywords
        super().__init__(**kwds) # call parent initializer
        
    def fit(self,X,y):
        num_samples, num_features = X.shape
        self.unique_ = np.unique(y) # get each unique class value
        num_unique_classes = len(self.unique_)
        self.classifiers_ = [] # will fill this array with binary classifiers
        
        for i,yval in enumerate(self.unique_): # for each unique value
            y_binary = y==yval # create a binary problem
            # train the binary classifier for this class
            # now this has regularization built into it
            blr = RegularizedBinaryLogisticRegression(eta=self.eta,
                                                      iterations=self.iters,
                                                      C=self.C)
            blr.fit(X,y_binary)
            # add the trained classifier to the list
            self.classifiers_.append(blr)
            
        # save all the weights into one matrix, separate column for each class
        self.w_ = np.hstack([x.w_ for x in self.classifiers_]).T

# %%
from sklearn import metrics as mt
lr_clf = MultiClassLogisticRegression(eta=0.1,iterations=10)
iter_num = 0
for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
    lr_clf.fit(X[train_indices],y[train_indices])  # train object
    y_hat = lr_clf.predict(X[test_indices]) # get test set precitions

    # print the accuracy and confusion matrix 
    print("====Iteration",iter_num," ====")
    print("accuracy", mt.accuracy_score(y[test_indices],y_hat)) 
    print("confusion matrix\n",mt.confusion_matrix(y[test_indices],y_hat))
# Out:
# ====Iteration 0  ====
# accuracy 0.7508532423208191
# confusion matrix
#  [[  0   0   1   0  10]
#  [  0   0   2   0  16]
#  [  0   0 106   0  25]
#  [  0   0   5   0   0]
#  [  0   0  14   0 114]]
# ====Iteration 1  ====
# accuracy 0.8054607508532423
# confusion matrix
#  [[  0   1   2   0   6]
#  [  0   0   5   0   7]
#  [  0   0 119   0  23]
#  [  0   0   3   0   0]
#  [  0   0   8   2 117]]
# ====Iteration 2  ====
# accuracy 0.726962457337884
# confusion matrix
#  [[  0   0   4   0  11]
#  [  0   0   2   0  21]
#  [  0   0  95   0  27]
#  [  0   0   6   0   0]
#  [  0   0   9   0 118]]

# %%
from sklearn.linear_model import LogisticRegression as SKLogisticRegression
from sklearn.metrics import accuracy_score
def lr_explor(cost, theSolver):
    lr_clf = MultiClassLogisticRegression(eta=0.1,iterations=10,
                                            C=float(cost), solver = theSolver) # get object
    acc = []
    for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
        lr_clf.fit(X[train_indices],y[train_indices])  # train object
        y_hat = lr_clf.predict(X[test_indices]) # get test set predictions
        acc.append(mt.accuracy_score(y[test_indices],y_hat))
        
    acc = np.array(acc)
    return acc

def lr_explor_sklearn_1():

    lr_sk = SKLogisticRegression(solver='liblinear') # all params default
    acc = []
    for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
        lr_sk.fit(X[train_indices],y[train_indices])  # train object
        y_hat = lr_sk.predict(X[test_indices]) # get test set predictions
        acc.append(mt.accuracy_score(y[test_indices],y_hat))
    
    acc = np.array(acc)
    return acc

def lr_explor_sklearn_2():

    lr_sk = SKLogisticRegression(solver='lbfgs') # all params default
    acc = []
    for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
        lr_sk.fit(X[train_indices],y[train_indices])  # train object
        y_hat = lr_sk.predict(X[test_indices]) # get test set predictions
        acc.append(mt.accuracy_score(y[test_indices],y_hat))
    
    acc = np.array(acc)
    return acc

# %%
# %%time
import time

costs = np.logspace(-5,1,20)
speed = np.zeros(4)

start = time.time()
steepestAscent = []
for c in costs:
    steepestAscent.append(lr_explor(c,BinaryLogisticRegression))
    
speed[0] = time.time() - start
stochasticGradientAscent = []
for c in costs:
    stochasticGradientAscent.append(lr_explor(c,StochasticLogisticRegression))
    
speed[1] = time.time() - start - speed[0]
newton = []
for c in costs:
    newton.append(lr_explor(c,HessianBinaryLogisticRegression))
    
speed[2] = time.time() - start - speed[1]
quasiNewton = []
for c in costs:
    quasiNewton.append(lr_explor(c,BFGSBinaryLogisticRegression))

speed[3] = time.time() - start - speed[2]
print(speed)
# Out:
# [ 0.32073379  0.07828784 16.03307629  2.37885022]
# Wall time: 18.4 s

# %%
fig, axs = plt.subplots(2, 2, figsize=(15, 10))
axs[0, 0].boxplot(steepestAscent)
axs[0, 0].set_title("Steepest Ascent")
axs[0, 1].boxplot(stochasticGradientAscent)
axs[0, 1].set_title("Stochastic Gradient Ascent")
axs[1, 0].boxplot(newton)
axs[1, 0].set_title("Newtons Method")
axs[1, 1].boxplot(quasiNewton)
axs[1, 1].set_title("Quasi Newtons Method")

plt.sca(axs[0, 0])
plt.yticks(np.arange(0,.9,0.05))
plt.xticks(range(1,len(costs)+1),['%.4f'%(c) for c in costs],rotation='vertical')
plt.sca(axs[1, 1])
plt.yticks(np.arange(0,.9,0.05))
plt.xticks(range(1,len(costs)+1),['%.4f'%(c) for c in costs],rotation='vertical')
plt.sca(axs[0, 1])
plt.yticks(np.arange(0,.9,0.05))
plt.xticks(range(1,len(costs)+1),['%.4f'%(c) for c in costs],rotation='vertical')
plt.sca(axs[1, 0])
plt.yticks(np.arange(0,.9,0.05))
plt.xticks(range(1,len(costs)+1),['%.4f'%(c) for c in costs],rotation='vertical')

for ax in axs.flat:
    ax.set(xlabel='C', ylabel='validation accuracy')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %%
bars_label = ['Steepest Ascent','Stochastic Gradient Ascent','Newtons Method','Quasi-Newtons Method']
plt.bar(bars_label,speed)
plt.ylabel('Run Speed (sec)')
plt.xlabel('Optimization Technique')
plt.xticks(range(len(bars_label)), bars_label, rotation='vertical')
plt.show()

for index, value in enumerate(speed):
    print(bars_label[index], ": ", round(value,4), "sec")
# Out:
# Steepest Ascent :  0.3207 sec
# Stochastic Gradient Ascent :  0.0783 sec
# Newtons Method :  16.0331 sec
# Quasi-Newtons Method :  2.3789 sec

# %% [markdown]
# Looking at all four optimization techniques, we clearly see that in terms of overall accuracy, the quasi newton method performs the best, followed by newtons method, steepest ascent and lastly stochastic gradient ascent. Examining the the cost paramter for regularizing the quasi newton method, we find that the accuracy remains high at cost values less than 0.01 after which the accuracy significantly drops. The optimal cost is found to be around 0.0008. While the quasi newton method is optimal for the model accuracy, we see that other techniques run much quicker. The stochastic gradient technique runs the fastest in 0.783 sec, followed by the steepest ascent at 0.3207 sec. The quasi newton method takes 2.379 sec and the original newtons method takes the longest by far at 16.033 sec. If we were to prioritize accuracy, then the quasi newton method would be the method to use. However, if speed and accuracy are both desired, the steepest ascent method could be a contender.

# %%
y_not_binary = y
runspeed = np.zeros(3)
accuracy_comparison = np.zeros(3)
labels = ['SKLearn Liblinear','SKLearn LBFGS','Custom Quasi Newton']

# %%
# %%time
#using liblearn
start = time.time()
sklearnOptimization_1 = lr_explor_sklearn_1()
runspeed[0] = time.time() - start
plt.title("SKLearn Logistic Regression Using Liblinear Scheme")
plt.boxplot(sklearnOptimization)
plt.xlabel('C')
plt.ylabel('validation accuracy')
plt.show()
accuracy_comparison[0] = np.mean(sklearnOptimization_1)
print('Average Accuracy Over 3 Iterations: ', accuracy_comparison[0])
# Out:
# Average Accuracy Over 3 Iterations:  0.8009101251422069
# Wall time: 97 ms

# %%
# %%time
#using lbfgs
start = time.time()
sklearnOptimization_2 = lr_explor_sklearn_2()
runspeed[1] = time.time() - start
plt.title("SKLearn Logistic Regression Using LBFGS Scheme")
plt.boxplot(sklearnOptimization)
plt.xlabel('C')
plt.ylabel('validation accuracy')
plt.show()
accuracy_comparison[1] = np.mean(sklearnOptimization_2)
print('Average Accuracy Over 3 Iterations: ',accuracy_comparison[1])
# Out:
# Average Accuracy Over 3 Iterations:  0.7895335608646189
# Wall time: 231 ms

# %%
# %%time
start = time.time()
bestOptimization = lr_explor(.0008,BFGSBinaryLogisticRegression)
runspeed[2] = time.time() - start
plt.title("Custom Implementation of Logistic Regression using Quasi-Newton Method")
plt.boxplot(bestOptimization)
plt.xlabel('C')
plt.ylabel('validation accuracy')
plt.show()
accuracy_comparison[2] = np.mean(bestOptimization)
print('Average Accuracy Over 3 Iterations: ', accuracy_comparison[2])
# Out:
# Average Accuracy Over 3 Iterations:  0.7736063708759954
# Wall time: 146 ms

# %%
x = np.arange(3)
ax1 = plt.subplot(1,1,1)
w = 0.3
plt.xticks(x + w /2, labels, rotation='vertical')
pop =ax1.bar(x, accuracy_comparison, width=w, color='tab:blue', align='center')
plt.ylabel('Accuracy Percent')
plt.ylim([0.5,1])

ax2 = ax1.twinx()
gdp =ax2.bar(x + w, runspeed, width=w,color='tab:red',align='center')
plt.ylabel('Time (sec)')
plt.legend([pop, gdp],['Accuracy', 'Speed'])
plt.show()

# %% [markdown]
# Comparing our custom version of the quasi newton method using a cost parameter of 0.0008 with two differen SKLearn regressions, we see that the SKlearn implementation using the liblearn solver was the fastest and most accurate. Our custom class came in second for runtime and last for accuracy. However, observing the accuracies, all three methods are quite comparable. This makes the runtime the main performance determiner, with the SKlearn liblearn solver around 4 times faster than our custom model and around 10 times faster than the SKlearn LBFGS solver.

# %% [markdown]
# ## Deployment (1 points total)
# Which implementation of logistic regression would you advise be used in a deployed machine learning model, your implementation or scikit-learn (or other third party)? Why?

# %% [markdown]
# From the results above, we would advise the SKlearn model using the liblearn solver to be the choice to use for future machine learning problems. This is due to its fast training and runtime, as well as its decently high accuracy score compared to the Sklearn model using the LBFGS solver and the custom Quasi-Newton solver. Additionally, the SKlearn implementation is easy to use.

# %% [markdown]
# ## Additional Analysis

# %%
def lr_explor_2(cost, theSolver, eta, ite):
    lr_clf = MultiClassLogisticRegression(eta=eta,iterations=ite,
                                            C=float(cost), solver = theSolver) # get object
    acc = []
    for iter_num, (train_indices, test_indices) in enumerate(cv_object.split(X,y)):
        lr_clf.fit(X[train_indices],y[train_indices])  # train object
        y_hat = lr_clf.predict(X[test_indices]) # get test set predictions
        acc.append(mt.accuracy_score(y[test_indices],y_hat))
        
    acc = np.array(acc)
    return acc


c = 0.0008

eta = np.linspace(0.05,1,20)
quasiNewton_eta = []
for e in eta:
    quasiNewton_eta.append(lr_explor_2(c,BFGSBinaryLogisticRegression,e,10))
    
ite = np.linspace(5,500,20)
quasiNewton_ite = []
for i in ite:
    quasiNewton_ite.append(lr_explor_2(c,BFGSBinaryLogisticRegression,0.5,i))

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 5))
axs[0].boxplot(quasiNewton)
axs[0].set_title("Quasi Newtons Method Changing C")
axs[1].boxplot(quasiNewton_eta)
axs[1].set_title("Quasi Newtons Method Changing Eta")
axs[2].boxplot(quasiNewton_ite)
axs[2].set_title("Quasi Newtons Method Changing Iterations")


plt.sca(axs[0])
plt.yticks(np.arange(0.5,.9,0.05))
plt.xticks(range(1,len(costs)+1),['%.4f'%(c) for c in costs],rotation='vertical')
plt.xlabel("C")
plt.sca(axs[1])
plt.yticks(np.arange(0.5,.9,0.05))
plt.xticks(range(1,len(eta)+1),['%.4f'%(c) for c in eta],rotation='vertical')
plt.xlabel("Eta")
plt.sca(axs[2])
plt.yticks(np.arange(0.5,.9,0.05))
plt.xticks(range(1,len(ite)+1),['%.4f'%(c) for c in ite],rotation='vertical')
plt.xlabel("Iterations")

for ax in axs.flat:
    ax.set(ylabel='validation accuracy')

# Hide x labels and tick labels for top plots and y ticks for right plots.
for ax in axs.flat:
    ax.label_outer()

# %% [markdown]
# The figure above plots the validation accuracy of the quasi-newtons method when varying the parameters C, eta, and number of iterations. By far, varying the cost parameter, C, through the given range produced the largest change in accuracy, with the optimal cost value ranging around 0.0008. Varying eta and iterations produced some variation in accuracy but no clear trend to say whether high or low values of these parameters yield higher accuracy.
